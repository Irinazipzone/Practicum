# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# Привет, меня зовут Александр Куимов. Я буду ревьюером твоего проекта. Ты можешь обращаться ко мне на "ты"😏 Надеюсь, тебя также не смутит, если я буду обращаться к тебе на "ты", но если это неудобно, обязательно скажи об этом!
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь реагировать на мои комментарии своими по шаблону, показанному чуть ниже. Это нужно, чтобы не создавалась путаница😉
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В случае, если решение на отдельном шаге является полностью правильным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#  В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
#
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b>👋:</b> В такой цветовой ячейке я прошу тебя оставлять свои комментарии. Если исправляешь проект на второй итерации и выше, не забывай пожалуйста указывать номер итерации, например, "Комментарий студента v.2".
# </div>
#
# <br/>
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой руководитель будет поступать также, и я пытаюсь подготовить тебя именно к работе датасаентистом. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!🤓

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Анализ" data-toc-modified-id="Анализ-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ</a></span><ul class="toc-item"><li><span><a href="#Ресемплирование" data-toc-modified-id="Ресемплирование-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Ресемплирование</a></span></li><li><span><a href="#Скользящее-среднее" data-toc-modified-id="Скользящее-среднее-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Скользящее среднее</a></span></li><li><span><a href="#Тренды-и-сезоны" data-toc-modified-id="Тренды-и-сезоны-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Тренды и сезоны</a></span></li><li><span><a href="#Разности-временного-ряда" data-toc-modified-id="Разности-временного-ряда-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Разности временного ряда</a></span></li></ul></li><li><span><a href="#Обучение" data-toc-modified-id="Обучение-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Обучение</a></span><ul class="toc-item"><li><span><a href="#Создание-новых-признаков" data-toc-modified-id="Создание-новых-признаков-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Создание новых признаков</a></span></li><li><span><a href="#Наборы-данных" data-toc-modified-id="Наборы-данных-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Наборы данных</a></span></li><li><span><a href="#Обучение-моделей" data-toc-modified-id="Обучение-моделей-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Обучение моделей</a></span><ul class="toc-item"><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Случайный лес</a></span></li><li><span><a href="#Линейная-регрессия" data-toc-modified-id="Линейная-регрессия-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Линейная регрессия</a></span></li><li><span><a href="#Градиентный-бустинг-Catboost" data-toc-modified-id="Градиентный-бустинг-Catboost-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>Градиентный бустинг Catboost</a></span></li></ul></li></ul></li><li><span><a href="#Тестирование" data-toc-modified-id="Тестирование-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Тестирование</a></span></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-проверки" data-toc-modified-id="Чек-лист-проверки-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист проверки</a></span></li></ul></div>

# %% [markdown]
# #  Прогнозирование заказов такси

# %% [markdown]
# В нашем распоряжении исторические данные о заказах такси в аэропортах. Чтобы привлекать больше водителей в период пиковой нагрузки, нужно спрогнозировать количество заказов такси на следующий час.
#
# **Цель:** Построить модель для предсказания количество заказа такси на следующий час.
#
# **Задачи:**
# - ресемплирование данных;
# - анализ временного ряда;
# - обучение моделей с различными гиперпараметрами;
# - метрика RMSE на тестовых данных не более 48.

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Вижу твое добавленное описание проекта. Молодец! Это поможет тебе расставлять акценты в выводах

# %% [markdown]
# ## Загрузка данных

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from sklearn.pipeline import make_pipeline
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, TimeSeriesSplit
from statsmodels.tsa.stattools import adfuller

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from catboost import CatBoostRegressor

from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler
from sklearn.compose import make_column_transformer, make_column_selector

from sklearn.metrics import mean_squared_error

# %%
RANDOM_STATE = 25

# %% [markdown]
# Загрузим данные:

# %%
df = pd.read_csv('/datasets/taxi.csv', index_col=[0], parse_dates=[0])

# %% [markdown]
# Проверим основную информацию о данных:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26496 entries, 2018-03-01 00:00:00 to 2018-08-31 23:50:00
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  26496 non-null  int64
# dtypes: int64(1)
# memory usage: 414.0 KB

# %%
df.head()
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00           9
# 2018-03-01 00:10:00          14
# 2018-03-01 00:20:00          28
# 2018-03-01 00:30:00          20
# 2018-03-01 00:40:00          32

# %% [markdown]
# Описательные статистики:

# %%
df.describe()
# Out:
#          num_orders
# count  26496.000000
# mean      14.070463
# std        9.211330
# min        0.000000
# 25%        8.000000
# 50%       13.000000
# 75%       19.000000
# max      119.000000

# %% [markdown]
# Проверим, в хронологическом ли порядке расположены даты и время:

# %%
df.index.is_monotonic
# Out:
# True

# %% [markdown]
# Данные расположены в хронологическом порядке. Построим диаграмму временного ряда:

# %%
plt.figure(figsize=(16, 5))
plt.plot(df)
plt.title('Диаграмма временного ряда')
plt.xlabel('Дата')
plt.ylabel('Количество заказов такси, шт')
plt.show()

# %% [markdown]
# **Вывод:**
# - пропуски в данных отсутствуют;
# - данные расположены в хронолоическом порядке.

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# С данными познакомились, проведен первичный аналитический осмотр!)  Полученная информация поможет нам в дальнейшем с предобработкой данных

# %% [markdown]
# ## Анализ

# %% [markdown]
# ### Ресемплирование

# %% [markdown]
# Проведем ресемплирование со значением в 1 час:

# %%
plt.figure(figsize=(16, 4))
#df = df.resample('1H').mean()
df = df.resample('1H').sum()
df.plot(ax=plt.gca())
plt.title('Диаграмма среднего количества заказа такси в час')
plt.xlabel('Дата')
plt.ylabel('Количество заказов такси, шт')
plt.show()

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b> В качестве агрегирующей функции следует использовать сумму, так лучше интерпретация (при использовании агрегирующей функции mean мы будем предсказывать среднее по 10 минутным интервалам за следующий час)

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b></b> Исправила на sum()
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# ### Скользящее среднее

# %% [markdown]
# Вычислим скользящее среднее за двое суток:

# %%
df['rolling_mean'] = df.rolling(48).mean()

# %%
plt.figure(figsize=(16, 4))
plt.plot(df)
plt.title('Диаграмма скользящего среднего количества заказа такси')
plt.xlabel('Дата')
plt.ylabel('Количество заказов такси, шт')
plt.show()

# %% [markdown]
# **Вывод:** на диаграммах среднего количества заказа такси в час и скользящего среднего отмечается восходящий тренд от марта к сентябрю.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера  <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Хорошо, что есть промежуточный вывод)

# %% [markdown]
# ### Тренды и сезоны

# %% [markdown]
# Разложим временной ряд на тренд и сезонную компоненту:

# %%
decomposed = seasonal_decompose(df['num_orders'])

# %%
plt.figure(figsize=(15, 10))

plt.subplot(311)
decomposed.trend.plot(ax=plt.gca())
plt.title('Тренды')

plt.subplot(312)
#Для сезонов возьмем промежуток времени 7 дней
decomposed.seasonal.plot(ax=plt.gca())
plt.title('Сезоны')

plt.subplot(313)
decomposed.resid.plot(ax=plt.gca())
plt.title('Остатки')

plt.tight_layout()

# %% [markdown]
# Рассмотрим сезоны более детально, в промежутке времени 7 дней:

# %%
plt.figure(figsize=(16, 4))
decomposed.seasonal.loc['2018-03-01':'2018-03-07'].plot(ax=plt.gca())
plt.title('Сезоны')
plt.show()

# %% [markdown]
# **Выводы:**
# - Наблюдается восходящий тренд от марта к сентябрю;
# - Наблюдаются сезоны. Циклично повторяются закономерноти: минимальное количество заказов в ночное время, максимальное количество заказов в вечернее время;
# - Есть остатки.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
#
# Желательно сначала провести декомпозицию всего ряда (изучить сезонность, тренд), а затем взять подотрезок: `seasonal_decompose(data).seasonal['2018-07-31':'2018-08-31']` (изучить сезонность)

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b></b> Спасибо за совет! Внесла изменения
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %% [markdown]
# ### Разности временного ряда

# %% [markdown]
# Проверим скользящее стандартное отклонение:

# %%
df['rolling_std'] = df['num_orders'].rolling(48).std()

# %%
plt.figure(figsize=(16, 4))
plt.plot(df)
plt.title('Диаграмма скользящего среднего и стандартного отклонения')
plt.xlabel('Дата')
plt.ylabel('Количество заказов такси, шт')
plt.show()

# %% [markdown]
# Проведет тест Дики-Фуллера для проверки ряда на стационарность:

# %%
ts = df['num_orders']
st_test = adfuller(ts, regression='ctt')

if st_test[1] < 0.05:
    print('Ряд стационарный')
else:
    print('Ряд нестационарный')
# Out:
# Ряд стационарный

# %%
#df = df - df.shift()

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#
# Перейдя к разности ты меняешь задачу, а значит теперь у тебя RMSE – задачи предсказания разности, а нужно измерить метрику исходной задачи. Нужно сделать обратное преобразование или вообще не переходить к разности
# </div>

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b></b> Добавила проверку на стационарность ряда. Временной ряд - стационарный. К разности не имеет смысла переходить.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %%
#plt.figure(figsize=(16, 4))
#plt.plot(df)
#plt.title('Диаграмма скользящего среднего и стандартного отклонения')
#plt.xlabel('Дата')
#plt.ylabel('Количество заказов такси, шт')
#plt.show()

# %% [markdown]
# ## Обучение

# %% [markdown]
# Прогнозирование количества такси является задачей регрессии. Для ее решения обучим три модели по алгоритмам:
# - Случайный лес;
# - Линейная регрессия;
# - Градиентый бустинг.
#
# Для оценки качества прогнозирования используем метрику RMSE.

# %% [markdown]
# ### Создание новых признаков

# %% [markdown]
# Добавим новые признаки: календарные, «отстающие значения» и скользящее среднее, Для создания новых признаков напишем функцию make_features:

# %%
def make_features(df, max_lag, rolling_mean_size):
    
    data = df.copy()
    
    data['month'] = data.index.month
    data['day'] = data.index.day
    data['dayofweek'] = data.index.dayofweek.astype('category')
    
    data.loc[(data.index.hour >= 0) & (data.index.hour < 6), 'times_of_day'] = 'night'
    data.loc[(data.index.hour >= 6) & (data.index.hour < 12), 'times_of_day'] = 'morning'
    data.loc[(data.index.hour >= 12) & (data.index.hour < 18), 'times_of_day'] = 'day'
    data.loc[(data.index.hour >= 18) & (data.index.hour < 24), 'times_of_day'] = 'evening'
    data['times_of_day'] = data['times_of_day'].astype('category')
    
    for lag in range(1, max_lag + 1):
        data['lag_{}'.format(lag)] = data['num_orders'].shift(lag)
    data['lag_week'] = data['num_orders'].shift(24 * 7)
        
    data['rolling_mean_{}'.format(rolling_mean_size)] = data['num_orders'].shift().\
                                                    rolling(rolling_mean_size).mean()
    return data

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# При генерации новых признаков желательно написать функцию, чтобы она возвращала новый датафрейм, а не изменяла глобальную переменную.
#
# 1. Это хорошая практика (не изменять глобальные переменные внутри функции), которая улучшает читаемость кода.
# 2. В какой-то момент может появиться необходимость подбирать некоторые параметры используемый внутри функции. В этот момент копирование датасета станет обязательным.
#
#
#
#
# Для этого внутри, в начале функции нужно задать новое имя датафрейму с `df.copy()`, в нем создать новые признаки, а в конце функции возвращать через `return` этот датафрейм
# </div>

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b></b> Спасибо за совет! Внесла изменения
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %%
df = make_features(df, 24, 24)
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4248 entries, 2018-03-08 00:00:00 to 2018-08-31 23:00:00
# Freq: H
# Data columns (total 33 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   num_orders       4248 non-null   int64
#  1   rolling_mean     4248 non-null   float64
#  2   rolling_std      4248 non-null   float64
#  3   month            4248 non-null   int64
#  4   day              4248 non-null   int64
#  5   dayofweek        4248 non-null   category
#  6   times_of_day     4248 non-null   category
#  7   lag_1            4248 non-null   float64
#  8   lag_2            4248 non-null   float64
#  9   lag_3            4248 non-null   float64
#  10  lag_4            4248 non-null   float64
#  11  lag_5            4248 non-null   float64
#  12  lag_6            4248 non-null   float64
#  13  lag_7            4248 non-null   float64
#  14  lag_8            4248 non-null   float64
# ...

# %% [markdown]
# ###  Наборы данных

# %% [markdown]
# Сформируем наборы данных:

# %%
X = df.drop(['num_orders'], axis=1)
y = df['num_orders']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=False, test_size=0.1)

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# Хорошо, что деление происходит последовательно по времени

# %% [markdown]
# Проверим корректность разбиения наборов данных:

# %%
print(X_train.index.min(), X_train.index.max())
print(X_test.index.min(), X_test.index.max())
# Out:
# 2018-03-08 00:00:00 2018-08-14 06:00:00
# 2018-08-14 07:00:00 2018-08-31 23:00:00

# %%
X_train.shape
# Out:
# (3823, 32)

# %%
X_test.shape
# Out:
# (425, 32)

# %% [markdown]
# Данные разбиты верно.

# %% [markdown]
# ### Обучение моделей

# %% [markdown]
# Для каждой модели соберем pipeline для подготовки признаков и обучения.
# Для корректного разбиения выборок, используем класс TimeSeriesSplit:

# %%
tscv = TimeSeriesSplit(n_splits=10)

# %% [markdown]
# Для отображения результатов обучения моделей создадим свобную таблицу total_ml:

# %%
total_ml = pd.DataFrame(columns=['Name_ml', 'RMSE'])

# %% [markdown]
# #### Случайный лес

# %%
transformer_rfr = make_column_transformer(
    (
        OrdinalEncoder(
            dtype='int16',
            handle_unknown='use_encoded_value',
            unknown_value=-1
        ), make_column_selector(dtype_include=['category'])
    ),
    (
        StandardScaler(
        ), make_column_selector(dtype_include=['int16', 'float64'])
    ),
    remainder='passthrough'
)

# %%
pipeline_rfr = make_pipeline(transformer_rfr, RandomForestRegressor(random_state=RANDOM_STATE))

# %%
param_rfr = {
    'randomforestregressor__max_depth':np.arange(5, 21, 5),
    'randomforestregressor__min_samples_leaf': np.arange(2, 10)
}

reg_rfr = GridSearchCV(pipeline_rfr, param_rfr, scoring='neg_root_mean_squared_error', cv=tscv)

reg_rfr.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=10, test_size=None),
#              estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ordinalencoder',
#                                                                          OrdinalEncoder(dtype='int16',
#                                                                                         handle_unknown='use_encoded_value',
#                                                                                         unknown_value=-1),
#                                                                          <sklearn.compose._column_transformer.make_column_selector obje...
#                                                                         ('standardscaler',
#                                                                          StandardScaler(),
# ...

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# Отлично, что применяется TimeSeriesSplit, а не простой сплиттер

# %%
total_ml = total_ml.append({'Name_ml': 'RandomForestRegressor', 'RMSE': np.sqrt((reg_rfr.best_score_)*(-1))},\
                           ignore_index=True)
total_ml
# Out:
#                  Name_ml      RMSE
# 0  RandomForestRegressor  4.722447

# %% [markdown]
# #### Линейная регрессия

# %% [markdown]
# Для линейной регрессии используем трансформеры OneHotEncoder и StandardScaler:

# %%
transformer_ln = make_column_transformer(
    (
        OneHotEncoder(
            dtype='uint8',
            handle_unknown='ignore'
        ), make_column_selector(dtype_include=['category'])
    ),
    (
        StandardScaler(
        ), make_column_selector(dtype_include=['int16', 'float64'])
    ),
    remainder='passthrough'
)

# %%
pipeline_ln = make_pipeline(transformer_ln, LinearRegression())

# %%
param_ln = {
    'linearregression__normalize':[False, True]
}

reg_ln = GridSearchCV(pipeline_ln, param_ln, scoring='neg_root_mean_squared_error', cv=tscv)

reg_ln.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=10, test_size=None),
#              estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('onehotencoder',
#                                                                          OneHotEncoder(dtype='uint8',
#                                                                                        handle_unknown='ignore'),
#                                                                          <sklearn.compose._column_transformer.make_column_selector object at 0x7f390c8f7ca0>),
#                                                                         ('standardscaler',
#                                                                          StandardScaler(),
# ...

# %%
total_ml = total_ml.append({'Name_ml': 'LinearRegression', 'RMSE': np.sqrt((reg_ln.best_score_)*(-1))},\
                           ignore_index=True)
total_ml
# Out:
#                  Name_ml      RMSE
# 0  RandomForestRegressor  4.722447
# 1       LinearRegression  4.778140

# %% [markdown]
# #### Градиентный бустинг Catboost

# %%
pipeline_ctb = make_pipeline(transformer_rfr, CatBoostRegressor(loss_function='RMSE', silent=True,\
                                                         learning_rate=0.1, n_estimators=100,\
                                                         random_state=RANDOM_STATE))

# %%
param_ctb = {'catboostregressor__max_depth': np.arange(8, 15)}

# %%
reg_ctb = GridSearchCV(pipeline_ctb, param_ctb, scoring='neg_root_mean_squared_error', cv=tscv)
reg_ctb.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=10, test_size=None),
#              estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ordinalencoder',
#                                                                          OrdinalEncoder(dtype='int16',
#                                                                                         handle_unknown='use_encoded_value',
#                                                                                         unknown_value=-1),
#                                                                          <sklearn.compose._column_transformer.make_column_selector object at 0x7f390ca9cc70>),
#                                                                         ('standardscaler',
# ...

# %% [markdown]
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# При работе с временными рядами не следует использовать стандартную кросс-валидацию, так как в определенный момент тренировочная выборка окажется позже валидационной. Для решения этой проблемы стоит использовать <a href="https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.TimeSeriesSplit.html">TimeSeriesSplit</a>. Объект этого типа нужно передать в параметр cv в метод основанный на кросс-валидации
#
# (это касается абсолютно всех моделей, всех cross_val_score и всех SearchCV)
# </div>

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b></b> Внесла изменения
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %%
total_ml = total_ml.append({'Name_ml': 'CatBoostRegressor', 'RMSE': np.sqrt((reg_ctb.best_score_)*(-1))},\
                           ignore_index=True)
total_ml
# Out:
#                  Name_ml      RMSE
# 0  RandomForestRegressor  4.722447
# 1       LinearRegression  4.778140
# 2      CatBoostRegressor  4.722631

# %% [markdown]
# Лучший результат показали модели по алгоритму градиентный бустинг и случацный лес. Проедпочтение отдаем градиентному бустингу

# %% [markdown]
#  <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:  </b>
#
# Молодец, что пробуешь разные модели в этом шаге)
# </div>

# %% [markdown]
# ## Тестирование

# %%
best_model = reg_ctb.best_estimator_

# %%
prediction = best_model.predict(X_test)

# %%
rms = mean_squared_error(y_test, prediction, squared=False)
rms
# Out:
# 42.30006833370067

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# В конце проекта желательно визуализировать результаты (построить 2 временных ряда на одном графике), показать предсказанные значения лучшей модели и реальные тестовые

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b></b> добавила график реальных значений и предсказанных
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>

# %%
plt.figure(figsize=(15,5))
plt.plot(np.array(y_test, np.int32), color = 'green', label = 'Реальные значения')
plt.plot(np.array(prediction, np.int32), color = 'blue', label='Предсказанные значения')
plt.legend()
plt.show()

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# В ходе работы был проведен анализ временного ряда:
# - выявлен восходящий тренд от марта к сентябрю;
# - выявленна сезонность в промежетках 1 день: минимальное количество заказов в ночное время, постепенный рост к вечернему времени, пик в вечернее время и резкое снижение к ночному времени.
#
# Для стационарности временного ряда вычислили его разность.
# Обучили три модели по алгоритмам: случайный лес, линейная регрессия и градиентный бустинг. Наилучший результат показала модель на основе градиентного бустинга со значением метрики RMSE 42.3

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# В конце проекта желательно визуализировать результаты (построить 2 временных ряда на одном графике), показать предсказанные значения лучшей модели и реальные тестовые

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
#
# <h2> Итоговый комментарий ревьюера <a class="tocSkip"> </h2>
#
#
# У меня сложилось хорошее общее впечатление о проекте, тебе удалось неплохо справиться с этим проектом. Молодец! Подготовлены данные для анализа, изучен каждый параметр. Все красиво визуализировано, построено несколько моделей регрессии и оценено их качество. Осмысленная аналитика и дельная модельная работа - многое удалось как надо)
#
# Отмечу отдельные положительные моменты проекта🙂:
#
# - в ходе проекта встречались  функции, помогающие избавиться от дублирования кода;
# - много красивых визуализаций в проекте и хорошая интерпретация;
# - при обучении моделей использована валидация и поиск гиперпараметров.
#
# Есть несколько моментов всего, на которые стоит ещё раз взглянуть, я указал их в моих комментариях по ходу проекта. Предлагаю тебе доработать проект по моим комментариям, чтобы довести его до совершенства.
#
#
#
# </div>

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# <h2> Комментарий студента: <a class="tocSkip"> </h2>
#
# <b></b> Александр, привет! Спасибо за улучшение моей работы! Внесла изменения по комментариям, добавила визуальзацию результатов
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
#
# <h2> Итоговый комментарий ревьюера 2 <a class="tocSkip"> </h2>
#
#
#
# Теперь почти идеально. Принимаю работу)
#
# Если хочешь лучше разобраться в теме, то могу посоветовать тебе:
#
# Полезная лекция про временные ряды: https://www.youtube.com/watch?v=u433nrxdf5k
#
# Б.Б. Демешев - временные ряды https://disk.yandex.ru/i/LiDHB-B3A6Lz5A
#
# Базовое применение ARIMA - https://colab.research.google.com/drive/17RnG91Eq8JBKyxToNzvCvjibfxum-oPj?usp=sharing
#
# Канторович - Анализ временных рядов https://yadi.sk/i/IOkUOS3hTXf3gg
# https://facebook.github.io/prophet/
#
# https://facebook.github.io/prophet/docs/quick_start.html#python-api
#
# https://nbviewer.jupyter.org/github/miptgirl/habra_materials/blob/master/prophet/habra_data.ipynb
#
#
#
# В этом проекте были отработаны все моменты.
#
# Успехов тебе в следующем спринте!
#
# Рад был помочь тебе)
#
# </div>

# %% [markdown]
# ## Чек-лист проверки

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке исполнения
# - [x]  Данные загружены и подготовлены
# - [x]  Данные проанализированы
# - [x]  Модель обучена, гиперпараметры подобраны
# - [x]  Качество моделей проверено, выводы сделаны
# - [x]  Значение *RMSE* на тестовой выборке не больше 48
